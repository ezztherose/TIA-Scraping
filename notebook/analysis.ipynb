# %% [markdown]
# # Analysis of the data set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append("..")
from utility import plot_settings

# %%
# Read csv file
df = pd.read_csv('../data/plastic-pollution.csv')

# Length of data set
print(len(df))

# drop Nan-values
df = df.dropna()

# len after cleaning
print(len(df))
# Out:
# 2340
# 170

# %%
# look at the top 5 rows 
df.head()
# Out:
#    Waste exports  Waste imports  Waste re-exports  Waste re-imports  \
# 3      37099.550        50016.0               1.0              20.0
# 6      74789.043        39095.0              13.0              40.0
# 7      96283.510        42108.0               7.0              55.0
# 8     123063.385        50993.0              71.0             199.0
# 9     137676.983       117330.0               5.0              30.0
#
#    Waste net exports  Waste exports per capita  Waste imports per capita  \
# 3             8637.0                  0.046398                  0.062552
# 6            20290.0                  0.089019                  0.046533
# 7            60555.0                  0.107117                  0.046846
# 8            72861.0                  0.133307                  0.055239
# 9            20463.0                  0.150196                  0.128000
#
#    Net exports per capita  Waste re-exports per capita  \
# 3                0.010802                     0.000002
# ...

# %% [markdown]
# Extracting the data from "World"

# %%
df_world = df.loc[df['Entity'] == 'World', :]

# %% [markdown]
# Look at the extracted data

# %%
df_world.head()
# Out:
#       Waste exports  Waste imports  Waste re-exports  Waste re-imports  \
# 2286   1.209566e+07     14020319.0         3101201.0            7792.0
# 2287   1.320718e+07     14267935.0         3179491.0            8307.0
# 2288   1.420482e+07     15207513.0         2976379.0            3209.0
# 2289   1.535767e+07     16166266.0         2715436.0            1428.0
# 2290   1.452772e+07     16216426.0         2659680.0             932.0
#
#       Waste net exports  Waste exports per capita  Waste imports per capita  \
# 2286         -1913097.0                  2.010107                  2.329955
# 2287         -1037234.0                  2.180845                  2.356003
# 2288         -1053360.0                  2.300532                  2.462922
# 2289          -819255.0                  2.402080                  2.528552
# 2290         -1743447.0                  2.263148                  2.526218
#
#       Net exports per capita  Waste re-exports per capita  \
# ...

# %% [markdown]
# Plot of the data

# %%
plt.plot(df_world['Year'], df_world['Waste exports'])
plt.ylabel('Waste Export')
plt.xlabel('Year')
plt.title('Overview of the waste export')
# Out:
# Text(0.5, 1.0, 'Overview of the waste export')
