# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Looking at data sets tha could work for the assignment...
#
# Helpers:
# ```py
# # split column
# str.split(',', expand=True)
#
# # Trimming
# .strip()
#
# # linking
# .join()
# .merge()
# .concat()
# ```
#
# Info:
# - Pivot tables good to use to see if the data is good or not (pandas)
# - merging data sets
#     - problems, not the same
#     - need some common poit to merge on
#     - inner join, left outer join, full outer join

# %%
df1 = pd.read_csv('../data/plastic-pollution.csv')
df2 = pd.read_csv('../data/armed-forces-personnel.csv')
df3 = pd.read_csv('../data/number-of-deaths-by-risk-factor.csv')
df4 = pd.read_csv('../data/annual-number-of-deaths-by-cause.csv')

print(f"file containing nan value: {df1.isnull().values.any()}")
print(f"file containing nan value: {df2.isnull().values.any()}")
print(f"file containing nan value: {df3.isnull().values.any()}")
print(f"file containing nan value: {df4.isnull().values.any()}")

print(f'Data Fram 1: {len(df1)}')
print(f'Data Fram 2: {len(df2)}')
print(f'Data Fram 3: {len(df3)}')
print(f'Data Fram 4: {len(df4)}')

df1 = df1.dropna()
df2 = df2.dropna()
df3 = df3.dropna()
df4 = df4.dropna()
# Out:
# file containing nan value: True
# file containing nan value: True
# file containing nan value: True
# file containing nan value: True
# Data Fram 1: 2340
# Data Fram 2: 5659
# Data Fram 3: 6840
# Data Fram 4: 7273

# %%
df1.head()
# Out:
#    Waste exports  Waste imports  Waste re-exports  Waste re-imports  \
# 3      37099.550        50016.0               1.0              20.0
# 6      74789.043        39095.0              13.0              40.0
# 7      96283.510        42108.0               7.0              55.0
# 8     123063.385        50993.0              71.0             199.0
# 9     137676.983       117330.0               5.0              30.0
#
#    Waste net exports  Waste exports per capita  Waste imports per capita  \
# 3             8637.0                  0.046398                  0.062552
# 6            20290.0                  0.089019                  0.046533
# 7            60555.0                  0.107117                  0.046846
# 8            72861.0                  0.133307                  0.055239
# 9            20463.0                  0.150196                  0.128000
#
#    Net exports per capita  Waste re-exports per capita  \
# 3                0.010802                     0.000002
# ...

# %%
df2.head()
# Out:
#         Entity Code  Year  Armed forces personnel, total
# 0  Afghanistan  AFG  1985                          47000
# 1  Afghanistan  AFG  1989                          55000
# 2  Afghanistan  AFG  1990                          58000
# 3  Afghanistan  AFG  1991                          45000
# 4  Afghanistan  AFG  1992                          45000

# %%
df3.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                               3169
# 1                                               3222
# 2                                               3395
# 3                                               3623
# 4                                               3788
#
#    Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                              25633
# 1                                              25872
# 2                                              26309
# 3                                              26961
# 4                                              27658
#
# ...

# %%
df4.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Deaths - Meningitis - Sex: Both - Age: All Ages (Number)  \
# 0                                             2933.0
# 1                                             2731.0
# 2                                             2460.0
# 3                                             2327.0
# 4                                             2254.0
#
#    Deaths - Alzheimer's disease and other dementias - Sex: Both - Age: All Ages (Number)  \
# 0                                             1402.0
# 1                                             1424.0
# ...

# %%
print(f"file containing nan value: {df1.isnull().values.any()}")
print(f"file containing nan value: {df2.isnull().values.any()}")
print(f"file containing nan value: {df3.isnull().values.any()}")
print(f"file containing nan value: {df4.isnull().values.any()}")


print(f'Data Fram 1: {len(df1)}')
print(f'Data Fram 2: {len(df2)}')
print(f'Data Fram 3: {len(df3)}')
print(f'Data Fram 4: {len(df4)}')
# Out:
# file containing nan value: False
# file containing nan value: False
# file containing nan value: False
# file containing nan value: False
# Data Fram 1: 170
# Data Fram 2: 5217
# Data Fram 3: 6150
# Data Fram 4: 176
