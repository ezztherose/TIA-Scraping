# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append("../src/utility/")
from utility import plot_settings
from utility import visualization
from utility import data_base as data

# %%
df_raw = data.read_csv('../data/global-food.csv')
data.get_length(df_raw)
#df = df.dropna()
#data.get_length(df)
df = df_raw.copy()
# Out:
# 12280

# %%
df.head()
# Out:
#    Product      Country  Year  Population  Production (t)  \
# 0      NaN  Afghanistan  1961     8790140             NaN
# 1      NaN  Afghanistan  1962     8969055             NaN
# 2      NaN  Afghanistan  1963     9157463             NaN
# 3      NaN  Afghanistan  1964     9355510             NaN
# 4      NaN  Afghanistan  1965     9565154             NaN
#
#    production__tonnes__per_capita  Production per capita (kg)  Yield (t/ha)  \
# 0                             NaN                         NaN           NaN
# 1                             NaN                         NaN           NaN
# 2                             NaN                         NaN           NaN
# 3                             NaN                         NaN           NaN
# 4                             NaN                         NaN           NaN
#
#    Yield (kg/animal)  Land Use (ha)  ...  other_uses__tonnes__per_capita  \
# 0                NaN            NaN  ...                             NaN
# ...

# %%
df = df_raw[['Country', 'Year', 'Population', 
            'Food supply (kcal per capita per day)', 
            'Food supply (Protein g per capita per day)', 
            'Food supply (Fat g per capita per day)']].copy()

# %%
df.head()
# Out:
#        Country  Year  Population  Food supply (kcal per capita per day)  \
# 0  Afghanistan  1961     8790140                              3054.9053
# 1  Afghanistan  1962     8969055                              2973.2468
# 2  Afghanistan  1963     9157463                              2751.7795
# 3  Afghanistan  1964     9355510                              3013.4424
# 4  Afghanistan  1965     9565154                              3017.7600
#
#    Food supply (Protein g per capita per day)  \
# 0                                   86.492840
# 1                                   84.580055
# 2                                   78.657250
# 3                                   85.198880
# 4                                   85.612100
#
#    Food supply (Fat g per capita per day)
# 0                               38.209236
# 1                               38.335213
# 2                               39.338820
# 3                               39.747234
# ...

# %%
df['Year'].unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019])
